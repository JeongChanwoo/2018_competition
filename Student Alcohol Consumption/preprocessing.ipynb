# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
math_data = pd.read_csv('./data/student-alcohol-consumption/student-mat.csv')
port_data = pd.read_csv('./data/student-alcohol-consumption/student-por.csv')

# %%
math_data.shape, port_data.shape
# Out:
# ((395, 33), (649, 33))

# %%
math_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
port_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
port_data['subject']='P'
math_data['subject']='M'

# %%
port_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#     ...   freetime goout  Dalc  Walc  health absences  G1  G2  G3 subject
# 0   ...          3     4     1     1       3        4   0  11  11       P
# 1   ...          3     3     1     1       3        2   9  11  11       P
# 2   ...          3     2     2     3       3        6  12  13  12       P
# 3   ...          2     2     1     1       5        0  14  14  14       P
# 4   ...          3     2     1     2       5        0  11  13  13       P
#
# [5 rows x 34 columns]

# %%
math_data.info(),port_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 34 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# ...

# %%
total_data = pd.concat(objs=[math_data, port_data],axis=0)

# %%
total_data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'subject'],
#       dtype='object')

# %%
total_data.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.130196 -0.138521    0.049216  -0.007870  0.282364
# Medu       -0.130196  1.000000  0.642063   -0.238181   0.090616 -0.187769
# Fedu       -0.138521  0.642063  1.000000   -0.196328   0.033458 -0.191390
# traveltime  0.049216 -0.238181 -0.196328    1.000000  -0.081328  0.087177
# studytime  -0.007870  0.090616  0.033458   -0.081328   1.000000 -0.152024
# failures    0.282364 -0.187769 -0.191390    0.087177  -0.152024  1.000000
# famrel      0.007162  0.015004  0.013066   -0.012578   0.012324 -0.053676
# freetime    0.002645  0.001054  0.002142   -0.007403  -0.094429  0.102679
# goout       0.118510  0.025614  0.030075    0.049740  -0.072941  0.074683
# Dalc        0.133453  0.001515 -0.000165    0.109423  -0.159665  0.116336
# Walc        0.098291 -0.029331  0.019524    0.084292  -0.229073  0.107432
# health     -0.029129 -0.013254  0.034288   -0.029002  -0.063044  0.048311
# ...

# %% [markdown]
# # 중복학생 제거

# %%
duplicated_data = total_data[total_data.duplicated(["school","sex","age","address","famsize", 
                        "Pstatus","Medu","Fedu","Mjob","Fjob", 
                        "reason","nursery","internet"])]

# %%
duplicated_data.sort_values(by=["school","sex","age","address","famsize", 
                        "Pstatus","Medu","Fedu","Mjob","Fjob", 
                        "reason","nursery","internet"])
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 95      GP   F   15       R     GT3       T     1     1   at_home     other
# 72      GP   F   15       R     GT3       T     1     1     other     other
# 39      GP   F   15       R     GT3       T     2     2   at_home     other
# 24      GP   F   15       R     GT3       T     2     4  services    health
# 165     GP   F   15       R     GT3       T     3     3  services  services
# 38      GP   F   15       R     GT3       T     3     4  services    health
# 130     GP   F   15       R     GT3       T     3     4  services   teacher
# 68      GP   F   15       R     LE3       T     2     2    health  services
# 69      GP   F   15       R     LE3       T     3     1     other     other
# 105     GP   F   15       U     GT3       A     3     3     other    health
# 56      GP   F   15       U     GT3       A     4     3  services  services
# ...

# %%
total_data = total_data.drop_duplicates(["school","sex","age","address","famsize", 
                        "Pstatus","Medu","Fedu","Mjob","Fjob", 
                        "reason","nursery","internet"])

# %%
total_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#     ...   freetime goout  Dalc  Walc  health absences  G1  G2  G3 subject
# 0   ...          3     4     1     1       3        6   5   6   6       M
# 1   ...          3     3     1     1       3        4   5   5   6       M
# 2   ...          3     2     2     3       3       10   7   8  10       M
# 3   ...          2     2     1     1       5        2  15  14  15       M
# 4   ...          3     2     1     2       5        4   6  10  10       M
#
# [5 rows x 34 columns]

# %%
# duplicated_data[(duplicated_data['school']=='GP') & (duplicated_data['sex']=='M') &
#                (duplicated_data['address']=='U') & (duplicated_data['Pstatus']=='T') & 
#                (duplicated_data['famsize']=='LE3')]

# %%
def colum_rearange(data):
    
    data["alc_total"] = (data.Dalc*5 + data.Walc*2)
    data["alc_average"] = (data.Dalc*5 + data.Walc*2)/7
    data["score_average"] = (data.G1 + data.G2 + data.G3)/3
    data["score_total"] = (data.G1 + data.G2 + data.G3)
    
    return data

# %%
total_data = colum_rearange(total_data.copy())

# %%
total_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#       ...     health absences  G1  G2  G3 subject alc_total alc_average  \
# 0     ...          3        6   5   6   6       M         7    1.000000
# 1     ...          3        4   5   5   6       M         7    1.000000
# 2     ...          3       10   7   8  10       M        16    2.285714
# 3     ...          5        2  15  14  15       M         7    1.000000
# 4     ...          5        4   6  10  10       M         9    1.285714
#
#   score_average score_total
# 0      5.666667          17
# 1      5.333333          16
# ...

# %%
total_data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'subject', 'alc_total',
#        'alc_average', 'score_average', 'score_total'],
#       dtype='object')

# %%
total_data['school'].value_counts()
# Out:
# GP    434
# MS    228
# Name: school, dtype: int64

# %%
def column_unique(data):
    unique_dict={}
    count_dict={}
    for column in data.columns:
        unique_dict[column] =  data[column].unique()
        count_dict[column] =  data[column].value_counts()
    
    return unique_dict, count_dict

# %%
unique_dict, count_dict = column_unique(total_data)

# %%
count_dict["Medu"]
# Out:
# 2    190
# 4    172
# 1    150
# 3    144
# 0      6
# Name: Medu, dtype: int64

# %%
total_data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  662.000000  662.000000  662.000000  662.000000  662.000000  662.000000
# mean    16.812689    2.492447    2.293051    1.564955    1.927492    0.332326
# std      1.269194    1.130958    1.094027    0.742799    0.827405    0.716024
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  662.000000  662.000000  662.000000  662.000000  662.000000  662.000000
# mean     3.938066    3.184290    3.172205    1.504532    2.282477    3.531722
# ...

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 662 entries, 0 to 642
# Data columns (total 38 columns):
# school           662 non-null object
# sex              662 non-null object
# age              662 non-null int64
# address          662 non-null object
# famsize          662 non-null object
# Pstatus          662 non-null object
# Medu             662 non-null int64
# Fedu             662 non-null int64
# Mjob             662 non-null object
# Fjob             662 non-null object
# reason           662 non-null object
# guardian         662 non-null object
# traveltime       662 non-null int64
# studytime        662 non-null int64
# failures         662 non-null int64
# schoolsup        662 non-null object
# famsup           662 non-null object
# paid             662 non-null object
# activities       662 non-null object
# nursery          662 non-null object
# higher           662 non-null object
# internet         662 non-null object
# ...

# %%
numeric_column = ['age','failures','absences','G1','G2','G3','score_average'] 
# ,'score_average','score_total'을 독립 변수로 우선 간주(단, Standard 스케일을 하기에 둘중 하나만 선택)

categoric_column = ['Medu' ,'Fedu', 'Mjob', 'Fjob','reason' ,'guardian']

ordinal_column = ['traveltime', 'studytime','famrel','freetime','goout','Dalc','Walc','health']

binary_column = ['school','sex','address', 'famsize', 'Pstatus','schoolsup','famsup','paid', 'activities', 'nursery' ,'higher',
                'internet', 'romantic', 'subject']

other_column  = ['alc_total','alc_average'] # 타겟값 칼럼 (학생의 개인적, 학업적, 가족 및 사회적 영향이 음주에 미치는 영향)

# %% [markdown]
# # Train_test split

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(total_data, test_size = 0.2, random_state = 42)

# %%
train_set=train_set.reset_index()
train_set.rename(columns={'index' : 'ID'},inplace=True)

test_set=test_set.reset_index()
test_set.rename(columns={'index' : 'ID'},inplace=True)

# %%
total_data = total_data.reset_index()
total_data.rename(columns={'index' : 'ID'},inplace=True)

# %%
total_id = total_data.ID

# %%
train_id = train_set.ID
test_id = test_set.ID

# %%
train_index = train_set.index
test_index = test_set.index

# %%
total_index= total_data.index

# %%
raw_total =

# %% [markdown]
# # Preprocessing

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Binarizer
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names]

# %%
class MyLabelBinarizer(BaseEstimator, TransformerMixin):#LabelBinarizer Pipline 지원 안함  0.19버전 부터
    def __init__(self,  attribute_names): 
        self.encoder_dict = {}
#         self.encoder = LabelBinarizer()
        self.attribute_names = attribute_names
        
        
    def fit(self, X, y=None):
        for attribute in self.attribute_names:
            lb = LabelBinarizer()
            self.encoder_dict[attribute] = lb.fit(X.loc[:, attribute])
            
#             self.encoder.fit(X)
        return self
    def transform(self, X, y=None):
        X = X[self.attribute_names]
        for col_index,attribute in enumerate(self.attribute_names):
            X.loc[:,attribute] = self.encoder_dict[attribute].transform(X.loc[:,attribute])
#             X[attribute] = self.encoder_dict[attribute].transform(X[attribute])
        
        return X
#         return self.encoder.transform(X)

# %%
class Get_dummies(BaseEstimator, TransformerMixin):
    def __init__(self,attribute_names = categoric_column):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return pd.get_dummies(X[self.attribute_names])

# %%
class Trans_dataframe(BaseEstimator, TransformerMixin):
    def __init__(self,attribute_names ):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return pd.DataFrame(X, columns=self.attribute_names)

# %%
num_pipline = Pipeline([
    ('selector' , DataFrameSelector(numeric_column)),
      ('std_scaler', StandardScaler()),
    ("trand_df" , Trans_dataframe(numeric_column))
])

ordinary_pipline = Pipeline([
    ('selector' , DataFrameSelector(ordinal_column)),
    ('mm_scaler' , MinMaxScaler()),
    ("trand_df" , Trans_dataframe(ordinal_column))
])

binary_pipline = Pipeline([
    ('selector' , DataFrameSelector(binary_column)),
    ('L_binarizer', MyLabelBinarizer(binary_column)),
    ("trand_df" , Trans_dataframe(binary_column))
])

cat_pipline = Pipeline([
    ('selector', DataFrameSelector(categoric_column)),
    ('get_dummies', Get_dummies())
])

# %%
# from sklearn.pipeline import FeatureUnion

# %%
# full_pipline = FeatureUnion(transformer_list=[
#     ("num_pipline", num_pipline),
#     ("ordinary_pipline", ordinary_pipline),

# #     ("cat_pipline", cat_pipline),
# ])

# %%
def preprocessing_data(data=None, index=None, kind = None):
    if str(kind)=='train':
        
        
        train_prepared_id = pd.DataFrame(train_id)
        train_prepared_num = num_pipline.fit_transform(data)#.reindex(index)
        train_prepared_ord = ordinary_pipline.fit_transform(data)#.reindex(index)
        train_prepared_bin = binary_pipline.fit_transform(data)#.reindex(index)
        train_prepared_cat = cat_pipline.fit_transform(data)
        
        train_prepared = pd.concat([train_prepared_id,train_prepared_num,train_prepared_ord, 
                                    train_prepared_bin,train_prepared_cat], axis=1)
        
        return train_prepared
        
        
    elif str(kind) == 'test':
        
        test_prepared_id = pd.DataFrame(test_id)
        test_prepared_num = num_pipline.transform(data)#.reindex(index)
        test_prepared_ord = ordinary_pipline.transform(data)#.reindex(index)
        test_prepared_bin = binary_pipline.transform(data)#.reindex(index)
        test_prepared_cat = cat_pipline.transform(data)
        
        test_prepared = pd.concat([test_prepared_id,test_prepared_num,test_prepared_ord, 
                                   test_prepared_bin,test_prepared_cat], axis=1)
        
        return test_prepared
        
    elif str(kind)=='total':
        total_prepared_id = pd.DataFrame(total_id)
        total_prepared_num = num_pipline.fit_transform(data)#.reindex(index)
        total_prepared_ord = ordinary_pipline.fit_transform(data)#.reindex(index)
        total_prepared_bin = binary_pipline.fit_transform(data)#.reindex(index)
        total_prepared_cat = cat_pipline.fit_transform(data)
        
        total_prepared = pd.concat([total_prepared_id,total_prepared_num,total_prepared_ord, 
                                   total_prepared_bin,total_prepared_cat], axis=1)
        
        return total_prepared

# %%
total_prepared = preprocessing_data(total_data, index=total_index, kind='total')

# %%
train_prepared = preprocessing_data(train_set, index=train_index, kind='train')

# %%
test_prapred = preprocessing_data(test_set, index=test_index, kind='test')

# %%
test_prapred.head()
# Out:
#     ID       age  failures  absences        G1        G2        G3  \
# 0  330  0.962519 -0.449410 -0.404816 -0.570068 -0.793286 -0.675253
# 1  525  0.160672 -0.449410 -0.684931  1.375519  0.919564  1.279379
# 2  413  3.368059  2.522313  2.256276 -0.570068 -0.222336 -0.186595
# 3  366  0.962519 -0.449410 -0.684931  0.726990  0.634089  0.546392
# 4  268  0.962519 -0.449410  0.715644 -0.245804 -0.507811 -0.186595
#
#    score_average  traveltime  studytime       ...        Fjob_other  \
# 0      -0.719200    0.000000   1.000000       ...                 1
# 1       1.251057    0.000000   0.666667       ...                 0
# 2      -0.325148    0.333333   0.333333       ...                 1
# 3       0.659980    0.333333   0.666667       ...                 0
# 4      -0.325148    0.000000   0.333333       ...                 1
#
#    Fjob_services  Fjob_teacher  reason_course  reason_home  reason_other  \
# 0              0             0              1            0             0
# ...

# %%
train_set['alc_average'].describe()
# Out:
# count    529.000000
# mean       1.697272
# std        0.903369
# min        1.000000
# 25%        1.000000
# 50%        1.285714
# 75%        2.142857
# max        5.000000
# Name: alc_average, dtype: float64

# %%
train_prepared = pd.concat([train_prepared,train_set['alc_average']], axis =1)
test_prapred = pd.concat([test_prapred,test_set['alc_average']], axis =1)

# %%
pd.to_pickle(train_prepared,path='./data/train_prepared_2_drop_dupli')
pd.to_pickle(test_prapred,path='./data/test_prepared_2_drop_dupli')

# %%
total_prepared = pd.concat([total_prepared,total_data['alc_average']], axis =1)

# %%
pd.to_pickle(total_prepared,path='./data/total_prepared_2_drop_dupli')

# %%
# raw_total = pd.concat([total_data,total_data['alc_average']],axis=1)

# %%
pd.to_pickle(total_data,path='./data/total_data_raw')
